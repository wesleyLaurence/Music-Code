# %% [markdown]
# # Live Data Visualizations

# %%
# import libraries
import sys
import time
import psutil
import matplotlib
import matplotlib.pyplot as plt
from music_code import music_code

# set animation parameters in matplotlib
# %matplotlib notebook
plt.rcParams['animation.html'] = 'jshtml'

# initialize
m = music_code.MusicCode(120)

# %% [markdown]
# ### Example 1

# %%
def stream_one():
    
    # define waveforms
    waveform1 = m.create_wave([200], 'sine', 1/16, wt_pos=1)
    waveform2 = m.create_wave([205], 'sine', 1/16, wt_pos=1)
    waveform3 = m.create_wave([210], 'sine', 1/16, wt_pos=1)

    # time 
    x = []

    # containers for amplitude values for each waveform
    y1 = []
    y2 = []
    y3 = []

    # iterate through waveform amplitude values and plot real time visualization above
    i=0
    for value in waveform1:

        # append next time step value
        x.append(i)

        # append next set of amplitude values
        y1.append(value)
        y2.append(waveform2[i])
        y3.append(waveform3[i])

        # plot waveforms
        ax.plot(x, y1, color='r')
        ax.plot(x, y2, color='b')
        ax.plot(x, y3, color='g')

        fig.canvas.draw()

        # moving window 
        #ax.set_xlim(left=max(0, i-50), right=max(0, i+50))

        # added time between each iteration
        #time.sleep(.1)

        i+=1

# %%
""" plot color key
red: 200 hz
blue: 205 hz
green: 210 hz

"""

# create figure for live data visualization
plt.close()
fig = plt.figure()
ax = fig.add_subplot(111)
ax.axis('off')
fig.show()

# run animation function
stream_one()

# %% [markdown]
# ### Example 2

# %%
def stream_two():
    
    # define individual waveforms
    waveform1 = m.create_wave([600], 'sine', 1/16, wt_pos=1).vol(1)
    waveform2 = m.create_wave([600], 'sine', 1/16, wt_pos=1).vol(1.2)
    waveform3 = m.create_wave([600], 'sine', 1/16, wt_pos=1).vol(1.4)
    waveform4 = m.create_wave([600], 'sine', 1/16, wt_pos=1).vol(1.6)
    waveform5 = m.create_wave([600], 'sine', 1/16, wt_pos=1).vol(1.8)
    waveform6 = m.create_wave([600], 'sine', 1/16, wt_pos=1).vol(2.0)
    waveform7 = m.create_wave([600], 'sine', 1/16, wt_pos=1).vol(2.2)
    waveform8 = m.create_wave([600], 'sine', 1/16, wt_pos=1).vol(2.4)
    waveform9 = m.create_wave([1200], 'sine', 1/16, wt_pos=1).vol(2.6)
    waveform10 = m.create_wave([1200], 'sine', 1/16, wt_pos=1).vol(2.8)
    waveform11 = m.create_wave([1200], 'sine', 1/16, wt_pos=1).vol(3.0)
    waveform12 = m.create_wave([1200], 'sine', 1/16, wt_pos=1).vol(3.2)
    waveform13 = m.create_wave([1200], 'sine', 1/16, wt_pos=1).vol(3.4)
    waveform14 = m.create_wave([1200], 'sine', 1/16, wt_pos=1).vol(3.6)
    waveform15 = m.create_wave([1200], 'sine', 1/16, wt_pos=1).vol(3.8)
    waveform16 = m.create_wave([1200], 'sine', 1/16, wt_pos=1).vol(4.0)

    i=0

    # time 
    x = []

    # containers for amplitude values for each waveform
    y1 = []
    y2 = []
    y3 = []
    y4 = []
    y5 = []
    y6 = []
    y7 = []
    y8 = []
    y9 = []
    y10 = []
    y11 = []
    y12 = []
    y13 = []
    y14 = []
    y15 = []
    y16 = []

    # iterate through waveform amplitude values and plot real time visualization above
    for value in waveform1:

        # append next time step value
        x.append(i)

        # append next set of amplitude values
        y1.append(value)
        y2.append(waveform2[i])
        y3.append(waveform3[i])
        y4.append(waveform4[i])
        y5.append(waveform5[i])
        y6.append(waveform6[i])
        y7.append(waveform7[i])
        y8.append(waveform8[i])
        y9.append(waveform9[i])
        y10.append(waveform10[i])
        y11.append(waveform11[i])
        y12.append(waveform12[i])
        y13.append(waveform13[i])
        y14.append(waveform14[i])
        y15.append(waveform15[i])
        y16.append(waveform16[i])

        # plot waveforms
        ax.plot(x, y1, color='r')
        ax.plot(x, y2, color='b')
        ax.plot(x, y3, color='m')
        ax.plot(x, y4, color='g')
        ax.plot(x, y5, color='c')
        ax.plot(x, y6, color='b')
        ax.plot(x, y7, color='m')
        ax.plot(x, y8, color='g')
        ax.plot(x, y9, color='r')
        ax.plot(x, y10, color='b')
        ax.plot(x, y11, color='m')
        ax.plot(x, y12, color='g')
        ax.plot(x, y13, color='c')
        ax.plot(x, y14, color='b')
        ax.plot(x, y15, color='m')
        ax.plot(x, y16, color='g')

        fig.canvas.draw()

        # moving window 
        #ax.set_xlim(left=max(0, i-50), right=max(0, i+50))

        # added time between each iteration
        #time.sleep(.1)

        i+=1

# %%
# create figure for live data visualization
plt.close()
fig = plt.figure()
ax = fig.add_subplot(111)
ax.axis('off')
fig.show()

# run animation function
stream_two()
