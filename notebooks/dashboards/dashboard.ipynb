# %% [markdown]
# # Music-Code
# #### Analytics Dashboard

# %%
from music_code import analytics

# connect to MySQL dashboard
d = analytics.Dashboard('musiccode')
# Out:
# User ID: wesley
# Password: ········

# %%
d.display()

# %%
# method usage breakdown
d.activity()['method'].value_counts()
# Out:
# fade          7969
# joinwaves     6495
# sequence       898
# arpeggio       581
# chord          571
# createwave     475
# sample         277
# rest           254
# volume         152
# viewmethod     105
# bounce          97
# addwaves        88
# pan             72
# lfo             70
# lpf             66
# loopmethod      57
# timemethod      46
# timeedit        42
# reverse          9
# delay            9
# hpf              9
# Name: method, dtype: int64

# %%
# SELECT * FROM table
d.select_table('chord')
# Out:
#         ChordLabel RootNote  WaveType  WtPos  Duration  TonalSystem    FadeIn  \
# ChordID
# 1            maj 7       C2      sine    1.0     1.000         12.0  0.007812
# 2            maj 7       C3      sine    1.0     0.250         12.0  0.007812
# 3            maj 9       A2       tri    1.0     0.250         12.0  0.007812
# 4            maj 9       A2       tri    1.0     0.250         12.0  0.007812
# 5            maj 9       C3  sine-tri    1.0     0.500         12.0  0.007812
# ...            ...      ...       ...    ...       ...          ...       ...
# 567      maj triad       C3       tri    1.0     0.125         12.0  0.007812
# 568      maj triad       C3       tri    1.0     0.250         12.0  0.007812
# 569      maj triad       C3       tri    1.0     0.500         12.0  0.007812
# 570      maj triad       C3       tri    1.0     1.000         12.0  0.007812
# 571      maj triad       C3       tri    1.0     2.000         12.0  0.007812
#
# ...
